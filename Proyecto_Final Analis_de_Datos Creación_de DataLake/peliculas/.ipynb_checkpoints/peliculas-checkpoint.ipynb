# %%
#Web Scraping de data set 1

import requests
from bs4 import BeautifulSoup

def extraer_datos_fila(fila):
    datos = []
    for celda in fila.find_all('td'):
        # Encuentro todas las etiquetas <span> dentro de la fila etiqueta td y las elimino
        for span in celda.find_all('span'):
            span.decompose()
        # Extraigo el texto de la etiqueta td después de eliminar las etiquetas <span> y su contenido
        texto = celda.get_text(strip=True)
        # Remuevo los caracteres no deseados del html
        texto = texto.replace('\xa0', '').replace('\u2009', '').replace('&','')
        datos.append(texto)
    return datos

listadopeliculas = []

try:
    #extraigo los datos del url y los almaceno en soup
    url = 'https://es.wikipedia.org/wiki/Anexo:Pel%C3%ADculas_con_las_mayores_recaudaciones'
    pedido_obtenido = requests.get(url)
    html_obtenido = pedido_obtenido.text
    soup = BeautifulSoup(html_obtenido, 'html.parser')
    
    #obtengo los datos exclusivamente de la tabla con el classname wikitable
    tabla = soup.find('table', class_='wikitable')
    if tabla:
        #si encuentro la tabla entra al bucle y acciona la funcion extraer datos fila y manda la fila despues retorna los datos fila y los almacena
        for fila in tabla.find_all('tr'):
            datos_fila = extraer_datos_fila(fila)
            if datos_fila:
                listadopeliculas.append(datos_fila)

except Exception as e:
    print(f'Ocurrió un error: {e}')

# Imprimir la lista de películas obtenidas
for pelicula in listadopeliculas:
    print(pelicula)
# Out:
# ['Lightning  Thunder', '2923706026', '785221649 (26,9%)', '2138484377 (73,1%)', '237000000', '20th Century Fox', '2029', 'James Cameron']
# ['Avengers: Endgame', '2799439100', '858373000 (30,7%)', '1941066100 (69,3%)', '356000000', 'Walt Disney Studios Motion Pictures', '2019', 'Anthony y Joe Russo']
# ['Lightning: Beastpocalypse part 1', '2320250281', '684075767 (29,5%)', '1636174514 (70,5%)', '356000000', 'Walt Disney Studios Motion Pictures', '2026', 'James Cameron']
# ['Lightning: Beastpocalypse part 2', '2264743305', '674292608 (29,8%)', '1590450697 (70,2%)', '200000000', '20th Century Fox/Paramount Pictures', '1997', 'James Cameron']
# ['Star Wars: Episodio VII - El despertar de la Fuerza', '2071310218', '936662225 (45,2%)', '1134647993 (54,8%)', '306000000', 'Walt Disney Studios Motion Pictures', '2027', 'J. J. Abrams']
# ...

# %%
#Lectura de la segunda base de datos

import pandas as pd

lectura = pd.read_csv("base_de_datos_2.csv", dtype=str) #con dtype corrijo el error de lectura al momento de tener casillas de tipo cientifica y almaceno todo en tipo string
lectura
# Out:
#                                          names       date_x score  \
# 0                                    Creed III  03/02/2023   73.0
# 1                     Avatar: The Way of Water  12/15/2022   78.0
# 2                  The Super Mario Bros. Movie  04/05/2023   76.0
# 3                                      Mummies  01/05/2023   70.0
# 4                                    Supercell  03/17/2023   61.0
# ...                                        ...          ...   ...
# 10173                       20th Century Women  12/28/2016   73.0
# 10174  Delta Force 2: The Colombian Connection  08/24/1990   54.0
# 10175                         The Russia House  12/21/1990   61.0
# 10176         Darkman II: The Return of Durant  07/11/1995   55.0
# 10177       The Swan Princess: A Royal Wedding  07/20/2020   70.0
#
#                                                    genre  \
# 0                                          Drama, Action
# ...

# %%
import pandas as pd
lectura2 = pd.read_csv("base_de_datos_3.csv", encoding='latin1')
lectura2
# Out:
#         imdbID                                   title  year     rating  \
# 0            1                              Carmencita  1894  NOT RATED
# 1            5                        Blacksmith Scene  1893    UNRATED
# 2            3                          Pauvre Pierrot  1892        NaN
# 3            8  Edison Kinetoscopic Record of a Sneeze  1894        NaN
# 4           10   Employees Leaving the Lumiere Factory  1895        NaN
# ...        ...                                     ...   ...        ...
# 46009  5005684                       The New Classmate  2015        NaN
# 46010  5013056      Untitled Christopher Nolan Project  2017        NaN
# 46011  5013980                  Die Turnschuh-Giganten  2016        NaN
# 46012  5016760                The Monster of Mangatiti  2015        NaN
# 46013  5023260                           The Last Word  2016        NaN
#
#                           genre    released              director  \
# ...

# %%
#Creamos el archivo .db para sqlite de los tres dataset en una sola base de datos y estableciendo conexion
import sqlite3
conexion = sqlite3.connect('databasesinarreglar.db')
cursor= conexion.cursor()

#Creamos la tabla para el primer dataset (webscraping)
cursor.execute('''
    CREATE TABLE IF NOT EXISTS PELICULASDATA1 (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        Nombre_de_película TEXT,
        Recaudacion_mundial TEXT,
        Taquilla_EEUU TEXT,
        Taquilla_fuera_de_EEUU TEXT,
        Presupuesto TEXT,
        Distribuidora TEXT,
        Año_de_estreno TEXT,
        Director TEXT
    )
''')


#Creamos la tabla para el segundo dataset
cursor.execute('''
    CREATE TABLE IF NOT EXISTS PELICULASDATA2 (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        names TEXT,
        date_x DATE,
        Score TEXT,
        genre TEXT,
        overview TEXT,
        crew TEXT,
        orig_title TEXT,
        status TEXT,
        orig_lang TEXT,
        budget_x TEXT,
        revenue TEXT,
        country TEXT
    )
''')


#Creamos la tabla para el segundo dataset
cursor.execute('''
    CREATE TABLE IF NOT EXISTS PELICULASDATA3 (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        imdbID TEXT,
        title TEXT,
        year DATE,
        rating TEXT,
        genre TEXT,
        released DATE,
        director TEXT,
        writer TEXT,
        cast TEXT,
        metacritic TEXT,
        imdbRating TEXT,
        imdbVotes TEXT,
        poster TEXT,
        language TEXT,
        country TEXT,
        lastupdated TEXT,
        type TEXT
    )
''')



conexion.commit()

for peliculas in listadopeliculas:
    cursor.execute('''
        INSERT INTO PELICULASDATA1 (Nombre_de_película, Recaudacion_mundial, Taquilla_EEUU, Taquilla_fuera_de_EEUU, Presupuesto, Distribuidora, Año_de_estreno, Director) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (peliculas[0], peliculas[1], peliculas[2], peliculas[3], peliculas[4], peliculas[5], peliculas[6], peliculas[7]))


# Insertar los datos del Dataset2 en la tabla de la base de datos2
lectura.to_sql('PELICULASDATA2', conexion, if_exists='append', index=False)


# Insertar los datos del Dataset3 en la tabla de la base de datos3
lectura2.to_sql('PELICULASDATA3', conexion, if_exists='append', index=False)

conexion.commit()

conexion.close()

# %%
#Posterior a ello nos conectamos a sqlite para extraer cada tabla (dataset) y almacenarla en un archivo que podamos editar los datos nulos o erroneos

# Conexión a la base de datos SQLite
conexion_sqlite = sqlite3.connect('databasesinarreglar.db')
cursor_sqlite = conexion_sqlite.cursor()

# Obtener los nombres de las columnas de la tabla PELICULASDATA1
cursor_sqlite.execute('PRAGMA table_info(PELICULASDATA1)')
columnas = cursor_sqlite.fetchall()
nombres_columnas = [columna[1] for columna in columnas]

# Ejecutar la consulta para obtener los datos
cursor_sqlite.execute('SELECT * FROM PELICULASDATA1')
datos = cursor_sqlite.fetchall()

# Convertir los datos en una lista de diccionarios
resultados1 = [dict(zip(nombres_columnas, fila)) for fila in datos]

# Guardar los resultados en un archivo CSV
guardar_a_csv(resultados1, 'resultados1.csv')

# Cerrar la conexión a la base de datos SQLite
conexion_sqlite.close()

lecturaresultado1 = pd.read_csv("resultados1.csv")
lecturaresultado1
# Out:
#      id                                 Nombre_de_película  \
# 0     1                                 Lightning  Thunder
# 1     2                                  Avengers: Endgame
# 2     3                   Lightning: Beastpocalypse part 1
# 3     4                   Lightning: Beastpocalypse part 2
# 4     5  Star Wars: Episodio VII - El despertar de la F...
# ..  ...                                                ...
# 95   96                                            Hi, Mom
# 96   97                                   Independence Day
# 97   98                                               Coco
# 98   99          Animales fantásticos y dónde encontrarlos
# 99  100                                      Shrek Tercero
#
#     Recaudacion_mundial      Taquilla_EEUU Taquilla_fuera_de_EEUU Presupuesto  \
# 0            2923706026  785221649 (26,9%)     2138484377 (73,1%)   237000000
# 1            2799439100  858373000 (30,7%)     1941066100 (69,3%)   356000000
# ...

# %%
lecturaresultado1.isnull().sum()  #verificamos si tiene datos nulos
# Out:
# id                        0
# Nombre_de_película        0
# Recaudacion_mundial       0
# Taquilla_EEUU             0
# Taquilla_fuera_de_EEUU    0
# Presupuesto               0
# Distribuidora             0
# Año_de_estreno            0
# Director                  0
# dtype: int64

# %%
#Nos volvemos a conectar a sqlite para extraer la tabla 2 (dataset) y almacenarla en un archivo que podamos editar los datos nulos o erroneos

# Conexión a la base de datos SQLite
conexion_sqlite = sqlite3.connect('databasesinarreglar.db')
cursor_sqlite = conexion_sqlite.cursor()

# Obtener los nombres de las columnas de la tabla PELICULASDATA1
cursor_sqlite.execute('PRAGMA table_info(PELICULASDATA2)')
columnas = cursor_sqlite.fetchall()
nombres_columnas = [columna[1] for columna in columnas]

# Ejecutar la consulta para obtener los datos
cursor_sqlite.execute('SELECT * FROM PELICULASDATA2')
datos = cursor_sqlite.fetchall()

# Convertir los datos en una lista de diccionarios
resultados1 = [dict(zip(nombres_columnas, fila)) for fila in datos]

# Guardar los resultados en un archivo CSV
guardar_a_csv(resultados1, 'resultados2.csv')

# Cerrar la conexión a la base de datos SQLite
conexion_sqlite.close()

lecturaresultado2 = pd.read_csv("resultados2.csv")
lecturaresultado2
# Out:
#           id                                    names       date_x  Score  \
# 0          1                                Creed III  03/02/2023    73.0
# 1          2                 Avatar: The Way of Water  12/15/2022    78.0
# 2          3              The Super Mario Bros. Movie  04/05/2023    76.0
# 3          4                                  Mummies  01/05/2023    70.0
# 4          5                                Supercell  03/17/2023    61.0
# ...      ...                                      ...          ...    ...
# 10173  10174                       20th Century Women  12/28/2016    73.0
# 10174  10175  Delta Force 2: The Colombian Connection  08/24/1990    54.0
# 10175  10176                         The Russia House  12/21/1990    61.0
# 10176  10177         Darkman II: The Return of Durant  07/11/1995    55.0
# 10177  10178       The Swan Princess: A Royal Wedding  07/20/2020    70.0
#
#                                                    genre  \
# ...

# %%
lecturaresultado2.isnull().sum() #Verificamos los datos nulos de la segunta tabla(dataset 2)
# Out:
# id             0
# names          0
# date_x         0
# Score          0
# genre         85
# overview       0
# crew          56
# orig_title     0
# status         0
# orig_lang      0
# budget_x       0
# revenue        0
# country        0
# dtype: int64

# %%
#Ver dato que mas se repite en la columna genre
columna = lecturaresultado2['genre']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# genre
# Drama               556
# Comedy              373
# Drama, Romance      268
# Horror              260
# Horror, Thriller    202
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna crew
columna = lecturaresultado2['crew']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# crew
# Scout Taylor-Compton, Laurie Strode, Tyler Mane, Michael Myers, Malcolm McDowell, Dr. Samuel Loomis, Daeg Faerch, Michael Myers, Age 10, Sheri Moon Zombie, Deborah Myers, Danielle Harris, Annie Brackett, Brad Dourif, Sheriff Leigh Brackett, William Forsythe, Ronnie White, Kristina Klebe, Lynda van der Klok    3
# Naomi Watts, Ann Darrow, Jack Black, Carl Denham, Adrien Brody, Jack Driscoll, Thomas Kretschmann, Captain Englehorn, Colin Hanks, Preston, Jamie Bell, Jimmy, Andy Serkis, Kong / Lumpy, Kyle Chandler, Bruce Baxter, Evan Parke, Hayes                                                                               3
# Aoi Koga, Ange (voice), Akira Sekine, Princess (voice), You Taichi, Dorothy (voice), Akari Kageyama, Beatrice (voice), Nozomi Furuki, Chise (voice), Takayuki Sugo, L (voice), Miyuki Sawashiro, 7 (voice), Hiroyuki Honda, Dollyshop (voice), Takumi Yamazaki, Colonel (voice)                                        3
# ...

# %%
#Cambio de datos de las columnas con datos nulos
valores_a_llenar = {'genre': 'Drama', 'crew': 'Scout Taylor-Compton, Laurie Strode, Tyler Mane, Michael Myers, Malcolm McDowell, Dr. Samuel Loomis, Daeg Faerch, Michael Myers, Age 10, Sheri Moon Zombie, Deborah Myers, Danielle Harris, Annie Brackett, Brad Dourif, Sheriff Leigh Brackett, William Forsythe, Ronnie White, Kristina Klebe, Lynda van der Klok'}
lecturaresultado2.fillna(valores_a_llenar, inplace=True)

# %%
lecturaresultado2.isnull().sum()  #Verificamos que no tenga columnas vacias
# Out:
# id            0
# names         0
# date_x        0
# Score         0
# genre         0
# overview      0
# crew          0
# orig_title    0
# status        0
# orig_lang     0
# budget_x      0
# revenue       0
# country       0
# dtype: int64

# %%
#Nos volvemos a conectar a sqlite para extraer la tabla 3 (dataset) y almacenarla en un archivo que podamos editar los datos nulos o erroneos

# Conexión a la base de datos SQLite
conexion_sqlite = sqlite3.connect('databasesinarreglar.db')
cursor_sqlite = conexion_sqlite.cursor()

# Obtener los nombres de las columnas de la tabla PELICULASDATA1
cursor_sqlite.execute('PRAGMA table_info(PELICULASDATA3)')
columnas = cursor_sqlite.fetchall()
nombres_columnas = [columna[1] for columna in columnas]

# Ejecutar la consulta para obtener los datos
cursor_sqlite.execute('SELECT * FROM PELICULASDATA3')
datos = cursor_sqlite.fetchall()

# Convertir los datos en una lista de diccionarios
resultados1 = [dict(zip(nombres_columnas, fila)) for fila in datos]

# Guardar los resultados en un archivo CSV
guardar_a_csv(resultados1, 'resultados3.csv')

# Cerrar la conexión a la base de datos SQLite
conexion_sqlite.close()

lecturaresultado3 = pd.read_csv("resultados3.csv")
lecturaresultado3
# Out:
#           id   imdbID                                   title  year  \
# 0          1        1                              Carmencita  1894
# 1          2        5                        Blacksmith Scene  1893
# 2          3        3                          Pauvre Pierrot  1892
# 3          4        8  Edison Kinetoscopic Record of a Sneeze  1894
# 4          5       10   Employees Leaving the Lumiere Factory  1895
# ...      ...      ...                                     ...   ...
# 46009  46010  5005684                       The New Classmate  2015
# 46010  46011  5013056      Untitled Christopher Nolan Project  2017
# 46011  46012  5013980                  Die Turnschuh-Giganten  2016
# 46012  46013  5016760                The Monster of Mangatiti  2015
# 46013  46014  5023260                           The Last Word  2016
#
#           rating                     genre    released              director  \
# ...

# %%
lecturaresultado3.isnull().sum() #Verificamos los datos nulos de la segunta tabla(dataset 3)
# Out:
# id                 0
# imdbID             0
# title              0
# year               0
# rating         21385
# genre            399
# released        3012
# director         605
# writer          3072
# cast            1086
# metacritic     36613
# imdbRating      1714
# imdbVotes       1715
# poster         10216
# language        1115
# country          184
# lastupdated        0
# type              38
# dtype: int64

# %%
#Ver dato que mas se repite en la columna rating

columna = lecturaresultado3['rating']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# rating
# R            9559
# PG-13        3344
# PG           2968
# APPROVED     2316
# NOT RATED    2272
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna genre

columna = lecturaresultado3['genre']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# genre
# Drama             5455
# Comedy            3275
# Documentary       2047
# Comedy, Drama     1643
# Drama, Romance    1392
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna released

columna = lecturaresultado3['released']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# released
# 9/1/2015     37
# 11/1/2013    33
# 4/17/2015    33
# 1/23/2015    30
# 3/1/2013     29
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna director

columna = lecturaresultado3['director']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# director
# John Ford           59
# Michael Curtiz      56
# Georges Melies      56
# Alfred Hitchcock    54
# Werner Herzog       53
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna writer

columna = lecturaresultado3['writer']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# writer
# Woody Allen                   41
# Werner Herzog                 32
# Ingmar Bergman                31
# William Shakespeare (play)    25
# Ki-duk Kim                    22
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna cast

columna = lecturaresultado3['cast']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# cast
# Georges Melies     29
# Mel Blanc          20
# Charles Chaplin    11
# Buster Keaton      11
# George Carlin       9
# Name: count, dtype: int64

# %%
#Calcular el promedio de la columna metacritic

promedio_metacritic = round(lecturaresultado3['metacritic'].mean(),2)
promedio_metacritic
# Out:
# 56.9

# %%
#Calcular el promedio de la columna imdbRating

promedio_imdbRating = round(lecturaresultado3['imdbRating'].mean(),2)
promedio_imdbRating
# Out:
# 6.38

# %%
#Calcular el promedio de la columna imdbVotes

promedio_imdbVotes = round(lecturaresultado3['imdbVotes'].mean(),2)
promedio_imdbVotes
# Out:
# 11800.55

# %%
#Ver dato que mas se repite en la columna poster

columna = lecturaresultado3['poster']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# poster
# https://m.media-amazon.com/images/M/MV5BMjAwMTA2NTQzOV5BMl5BanBnXkFtZTcwNTg1NTIyMQ@@._V1_SX300.jpg    6
# https://m.media-amazon.com/images/M/MV5BMTcwMzI5NjIzOF5BMl5BanBnXkFtZTcwNDYwNDcxMQ@@._V1_SX300.jpg    6
# https://m.media-amazon.com/images/M/MV5BOTU5MTUwNTg5N15BMl5BanBnXkFtZTcwOTk0NDIyMQ@@._V1_SX300.jpg    6
# https://m.media-amazon.com/images/M/MV5BMTk1NDIxODA2Ml5BMl5BanBnXkFtZTcwMzk4MjAzMQ@@._V1_SX300.jpg    6
# https://m.media-amazon.com/images/M/MV5BMTk3NjQ1OTk4M15BMl5BanBnXkFtZTYwMDczNDg5._V1_SX300.jpg        6
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna language

columna = lecturaresultado3['language']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# language
# English     25325
# French       1784
# Italian      1480
# Japanese     1290
# Spanish       875
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna country

columna = lecturaresultado3['country']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# country
# USA       20589
# UK         2550
# France     1683
# Japan      1468
# Italy      1208
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna lastupdated

columna = lecturaresultado3['lastupdated']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# lastupdated
# 00:08.3    10
# 00:23.8     8
# 03:16.4     8
# 02:32.4     8
# 00:11.9     8
# Name: count, dtype: int64

# %%
#Ver dato que mas se repite en la columna type

columna = lecturaresultado3['type']
dato_mas_comun = columna.value_counts().head(5)
dato_mas_comun
# Out:
# type
# movie     45585
# series      391
# Name: count, dtype: int64

# %%
#Cambio de datos de las columnas con datos nulos
valores_a_llenar = {'rating': 'R', 'genre': 'Drama','released':'1895-03-22','director':'John Ford','writer':'Woody Allen','cast':'Georges Melies','metacritic':56.9,'imdbRating':6.38,'imdbVotes':11800.55,'poster':'https://m.media-amazon.com/images/M/MV5BMjAwMTA2NTQzOV5BMl5BanBnXkFtZTcwNTg1NTIyMQ@@._V1_SX300.jpg','language':'English','country':'USA','lastupdated':'00:08.3','type':'movie'}
lecturaresultado3.fillna(valores_a_llenar, inplace=True)

# %%
lecturaresultado3.isnull().sum() #Verificamos que ya no existan columnas con datos vacios
# Out:
# id             0
# imdbID         0
# title          0
# year           0
# rating         0
# genre          0
# released       0
# director       0
# writer         0
# cast           0
# metacritic     0
# imdbRating     0
# imdbVotes      0
# poster         0
# language       0
# country        0
# lastupdated    0
# type           0
# dtype: int64

# %%
#Realizamos la conexión con Mongo DB
import pymongo


# Convertir el DataFrame a una lista de diccionarios
dataset1 = lecturaresultado1.to_dict(orient='records')
dataset2 = lecturaresultado2.to_dict(orient='records')
dataset3 = lecturaresultado3.to_dict(orient='records')


# Conectar con MongoDB
client = pymongo.MongoClient('mongodb+srv://Alexis:Alexis@cluster0.dm8ijqo.mongodb.net/')

# Seleccionar la base de datos y la colección
db = client.peliculas  # Nombre de tu base de datos
tabla = db.datasetpeliculas1  # Nombre de tu colección
tabla2 = db.datasetpeliculas2  # Nombre de tu colección
tabla3 = db.datasetpeliculas3  # Nombre de tu colección


# Insertar los datos en la colección
try:
    resultado = tabla.insert_many(dataset1)
    resultado2 = tabla2.insert_many(dataset2)
    resultado3 = tabla3.insert_many(dataset3)
    print(f'Insertados {len(resultado.inserted_ids)} documentos')
    print(f'Insertados {len(resultado2.inserted_ids)} documentos')
    print(f'Insertados {len(resultado3.inserted_ids)} documentos')
except Exception as e:
    print("Ocurrió un error:", e)
# Out:
# Insertados 100 documentos
# Insertados 10178 documentos
# Insertados 46014 documentos
